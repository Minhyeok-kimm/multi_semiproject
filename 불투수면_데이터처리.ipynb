# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/서울특별시_자치구별 불투수면적 현황_20201231.csv', encoding='cp949')
df.head()
# Out:
#    연번  자치구  구 전체면적(헥타르)   불투수면적(헥타르)   불투수면적 비율(퍼센트) 비고
# 0   1  종로구       2312.4         971.6          42.02
# 1   2   중구        998.2         749.2          75.05
# 2   3  용산구       2196.7         970.0          44.16
# 3   4  성동구       1642.2        1040.4          63.36
# 4   5  광진구       1788.9        1023.9          57.23

# %%
df['불투수면적 비율'] = df[' 불투수면적(헥타르) '] / df['구 전체면적(헥타르)']

df2 = df[['자치구', '불투수면적 비율']]
df2
# Out:
#      자치구  불투수면적 비율
# 0    종로구  0.420170
# 1     중구  0.750551
# 2    용산구  0.441571
# 3    성동구  0.633540
# 4    광진구  0.572363
# 5   동대문구  0.738865
# 6    중랑구  0.585059
# 7    성북구  0.524748
# 8    강북구  0.361560
# 9    도봉구  0.404197
# 10   노원구  0.369990
# 11   은평구  0.384954
# 12  서대문구  0.529234
# 13   마포구  0.536892
# 14   양천구  0.672809
# 15   강서구  0.397390
# 16   구로구  0.606688
# 17   금천구  0.603816
# 18  영등포구  0.596109
# 19   동작구  0.600425
# 20   관악구  0.391877
# 21   서초구  0.361815
# 22   강남구  0.548862
# 23   송파구  0.572412
# 24   강동구  0.471826

# %%
df2.to_csv('use_data/자치구별_불투수면적_가공.csv', index=False)
